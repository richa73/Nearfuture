# %% [markdown]
# # Spacy Pipeline

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc_1=nlp('NMIMS is the all-encompassing educational platform for diverse fields of career such as Engineering, Science and Technology, Management, Commerce, Architecture, Law, Economics, Pharmacy, Aviation, Design, Performing Arts, Liberal Arts, Hospitality Management, Mathematical Science, Branding and Advertising, Agricultural Sciences and much more..Ideal for forward-thinking and new-age young professionals.Strong industry interface & corporate relationships with 1348+ companies.Research-backed updated curriculum, along with 2400+ published papers to its credit.Continuing the legacy of quality education.Focus on employability of students through evolved pedagogy.Pursuing excellence in technological and management research')

# %%
type(doc_1)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ## Tokenizer

# %%
for token in doc_1:
    print(token)
# Out:
# NMIMS
# is
# the
# all
# -
# encompassing
# educational
# platform
# for
# diverse
# fields
# of
# career
# such
# as
# Engineering
# ,
# Science
# and
# Technology
# ,
# Management
# ,
# Commerce
# ,
# Architecture
# ,
# Law
# ,
# Economics
# ,
# Pharmacy
# ,
# Aviation
# ,
# Design
# ,
# Performing
# Arts
# ,
# Liberal
# Arts
# ,
# Hospitality
# Management
# ,
# Mathematical
# Science
# ,
# Branding
# and
# Advertising
# ,
# Agricultural
# Sciences
# and
# much
# more
# ..
# Ideal
# for
# forward
# -
# thinking
# and
# new
# -
# age
# young
# professionals
# .
# Strong
# industry
# interface
# &
# corporate
# relationships
# with
# 1348
# +
# companies
# .
# Research
# -
# backed
# updated
# curriculum
# ,
# along
# with
# 2400
# +
# published
# papers
# to
# its
# credit
# .
# Continuing
# the
# legacy
# of
# quality
# education
# .
# Focus
# on
# employability
# of
# students
# through
# evolved
# pedagogy
# .
# Pursuing
# excellence
# in
# technological
# and
# management
# research

# %% [markdown]
# ## Stream of strings as input
#
# When there is a stream of strings as input, we need to
#
# use nlp.pipe() instead of nlp().

# %% [markdown]
# ### List of strings

# %%
text_2=['Today is Monday','Tomorrow is Tuesday',
       'Yesterday was a holiday']

# %%
type(text_2)
# Out:
# list

# %%
text_2[0]
# Out:
# 'Today is Monday'

# %%
text_2[1]
# Out:
# 'Tomorrow is Tuesday'

# %%
for sentence in nlp.pipe(text_2):
    print(sentence)
# Out:
# Today is Monday
# Tomorrow is Tuesday
# Yesterday was a holiday

# %%
# Tokens

for sentence in nlp.pipe(text_2):
    print(sentence)
    for token in sentence:
        print(token)
# Out:
# Today is Monday
# Today
# is
# Monday
# Tomorrow is Tuesday
# Tomorrow
# is
# Tuesday
# Yesterday was a holiday
# Yesterday
# was
# a
# holiday

# %% [markdown]
# ### Tuple of strings

# %%
text_3=('Today is Monday','Tomorrow is Tuesday',
       'Yesterday was Sundaya,a holiday')

# %%
type(text_3)
# Out:
# tuple

# %%
text_3[0]
# Out:
# 'Today is Monday'

# %%
for sent in nlp.pipe(text_3):
    print(sent)
    for token in sent:
        print(token)
# Out:
# Today is Monday
# Today
# is
# Monday
# Tomorrow is Tuesday
# Tomorrow
# is
# Tuesday
# Yesterday was Sundaya,a holiday
# Yesterday
# was
# Sundaya
# ,
# a
# holiday

# %% [markdown]
# ### List of tuples

# %%
text_4=[('Today is Monday'),('Tomorrow is Tuesday'),
       ('Yesterday was Sundaya,a holiday')]

# %%
type(text_4)
# Out:
# list

# %%
text_4[0]
# Out:
# 'Today is Monday'

# %%
sent_count=0
for sent in nlp.pipe(text_4):
    sent_count=sent_count+1
    print(sent_count,'=>',sent)
    for token in sent:
        print(token)
# Out:
# 1 => Today is Monday
# Today
# is
# Monday
# 2 => Tomorrow is Tuesday
# Tomorrow
# is
# Tuesday
# 3 => Yesterday was Sundaya,a holiday
# Yesterday
# was
# Sundaya
# ,
# a
# holiday

# %% [markdown]
# ### A DataFrame

# %%
text_2
# Out:
# ['Today is Monday', 'Tomorrow is Tuesday', 'Yesterday was a holiday']

# %%
import pandas as pd

# %%
text_df=pd.DataFrame(text_2,columns=['Sentence'])
text_df
# Out:
#                   Sentence
# 0          Today is Monday
# 1      Tomorrow is Tuesday
# 2  Yesterday was a holiday

# %%
text_df['Sentence']
# Out:
# 0            Today is Monday
# 1        Tomorrow is Tuesday
# 2    Yesterday was a holiday
# Name: Sentence, dtype: object

# %%
for sent in nlp.pipe(text_df['Sentence']):
    print(sent)
    for token in sent:
        print(token)
# Out:
# Today is Monday
# Today
# is
# Monday
# Tomorrow is Tuesday
# Tomorrow
# is
# Tuesday
# Yesterday was a holiday
# Yesterday
# was
# a
# holiday

# %%
doc_1
# Out:
# NMIMS is the all-encompassing educational platform for diverse fields of career such as Engineering, Science and Technology, Management, Commerce, Architecture, Law, Economics, Pharmacy, Aviation, Design, Performing Arts, Liberal Arts, Hospitality Management, Mathematical Science, Branding and Advertising, Agricultural Sciences and much more..Ideal for forward-thinking and new-age young professionals.Strong industry interface & corporate relationships with 1348+ companies.Research-backed updated curriculum, along with 2400+ published papers to its credit.Continuing the legacy of quality education.Focus on employability of students through evolved pedagogy.Pursuing excellence in technological and management research

# %%
for token in doc_1:
    print(token)
# Out:
# NMIMS
# is
# the
# all
# -
# encompassing
# educational
# platform
# for
# diverse
# fields
# of
# career
# such
# as
# Engineering
# ,
# Science
# and
# Technology
# ,
# Management
# ,
# Commerce
# ,
# Architecture
# ,
# Law
# ,
# Economics
# ,
# Pharmacy
# ,
# Aviation
# ,
# Design
# ,
# Performing
# Arts
# ,
# Liberal
# Arts
# ,
# Hospitality
# Management
# ,
# Mathematical
# Science
# ,
# Branding
# and
# Advertising
# ,
# Agricultural
# Sciences
# and
# much
# more
# ..
# Ideal
# for
# forward
# -
# thinking
# and
# new
# -
# age
# young
# professionals
# .
# Strong
# industry
# interface
# &
# corporate
# relationships
# with
# 1348
# +
# companies
# .
# Research
# -
# backed
# updated
# curriculum
# ,
# along
# with
# 2400
# +
# published
# papers
# to
# its
# credit
# .
# Continuing
# the
# legacy
# of
# quality
# education
# .
# Focus
# on
# employability
# of
# students
# through
# evolved
# pedagogy
# .
# Pursuing
# excellence
# in
# technological
# and
# management
# research

# %% [markdown]
# ## Separating doc into sentences

# %%
for sent in doc_1.sents:
    print(sent)
# Out:
# NMIMS is the all-encompassing educational platform for diverse fields of career such as Engineering, Science and Technology, Management, Commerce, Architecture, Law, Economics, Pharmacy, Aviation, Design, Performing Arts, Liberal Arts, Hospitality Management, Mathematical Science, Branding and Advertising, Agricultural Sciences and much more..
# Ideal for forward-thinking and new-age young professionals.
# Strong industry interface & corporate relationships with 1348+ companies.
# Research-backed updated curriculum, along with 2400+ published papers to its credit.
# Continuing the legacy of quality education.
# Focus on employability of students through evolved pedagogy.
# Pursuing excellence in technological and management research

# %%
sent_count=0
for sent in doc_1.sents:
    sent_count=sent_count+1
    print(sent_count,'==>',sent)
# Out:
# 1 ==> NMIMS is the all-encompassing educational platform for diverse fields of career such as Engineering, Science and Technology, Management, Commerce, Architecture, Law, Economics, Pharmacy, Aviation, Design, Performing Arts, Liberal Arts, Hospitality Management, Mathematical Science, Branding and Advertising, Agricultural Sciences and much more..
# 2 ==> Ideal for forward-thinking and new-age young professionals.
# 3 ==> Strong industry interface & corporate relationships with 1348+ companies.
# 4 ==> Research-backed updated curriculum, along with 2400+ published papers to its credit.
# 5 ==> Continuing the legacy of quality education.
# 6 ==> Focus on employability of students through evolved pedagogy.
# 7 ==> Pursuing excellence in technological and management research

# %% [markdown]
# ## Tagger

# %%
for token in doc_1:
    print(token.text,'==>',token.tag_)
# Out:
# NMIMS ==> NNS
# is ==> VBZ
# the ==> DT
# all ==> RB
# - ==> HYPH
# encompassing ==> VBG
# educational ==> JJ
# platform ==> NN
# for ==> IN
# diverse ==> JJ
# fields ==> NNS
# of ==> IN
# career ==> NN
# such ==> JJ
# as ==> IN
# Engineering ==> NNP
# , ==> ,
# Science ==> NNP
# and ==> CC
# Technology ==> NNP
# , ==> ,
# Management ==> NNP
# , ==> ,
# Commerce ==> NNP
# , ==> ,
# Architecture ==> NNP
# , ==> ,
# Law ==> NNP
# , ==> ,
# Economics ==> NNP
# , ==> ,
# Pharmacy ==> NNP
# , ==> ,
# Aviation ==> NNP
# , ==> ,
# Design ==> NNP
# , ==> ,
# Performing ==> VBG
# Arts ==> NNS
# , ==> ,
# Liberal ==> NNP
# Arts ==> NNP
# , ==> ,
# Hospitality ==> NNP
# Management ==> NNP
# , ==> ,
# Mathematical ==> NNP
# Science ==> NNP
# , ==> ,
# Branding ==> NNP
# and ==> CC
# Advertising ==> NNP
# , ==> ,
# Agricultural ==> NNP
# Sciences ==> NNPS
# and ==> CC
# much ==> RB
# more ==> JJR
# .. ==> .
# Ideal ==> JJ
# for ==> IN
# forward ==> RB
# - ==> HYPH
# thinking ==> NN
# and ==> CC
# new ==> JJ
# - ==> HYPH
# age ==> NN
# young ==> JJ
# professionals ==> NNS
# . ==> .
# Strong ==> JJ
# industry ==> NN
# interface ==> NN
# & ==> CC
# corporate ==> JJ
# relationships ==> NNS
# with ==> IN
# 1348 ==> CD
# + ==> CD
# companies ==> NNS
# . ==> .
# Research ==> NN
# - ==> HYPH
# backed ==> VBN
# updated ==> VBN
# curriculum ==> NN
# , ==> ,
# along ==> IN
# with ==> IN
# 2400 ==> CD
# + ==> CC
# published ==> VBN
# papers ==> NNS
# to ==> IN
# its ==> PRP$
# credit ==> NN
# . ==> .
# Continuing ==> VBG
# the ==> DT
# legacy ==> NN
# of ==> IN
# quality ==> NN
# education ==> NN
# . ==> .
# Focus ==> NN
# on ==> IN
# employability ==> NN
# of ==> IN
# students ==> NNS
# through ==> IN
# evolved ==> VBN
# pedagogy ==> NN
# . ==> .
# Pursuing ==> VBG
# excellence ==> NN
# in ==> IN
# technological ==> JJ
# and ==> CC
# management ==> NN
# research ==> NN

# %%
spacy.explain('NNS')
# Out:
# 'noun, plural'

# %%
spacy.explain('VBG')
# Out:
# 'verb, gerund or present participle'

# %%
for token in doc_1:
    print(token.text,'==>',token.tag)
# Out:
# NMIMS ==> 783433942507015291
# is ==> 13927759927860985106
# the ==> 15267657372422890137
# all ==> 164681854541413346
# - ==> 8214596291009089021
# encompassing ==> 1534113631682161808
# educational ==> 10554686591937588953
# platform ==> 15308085513773655218
# for ==> 1292078113972184607
# diverse ==> 10554686591937588953
# fields ==> 783433942507015291
# of ==> 1292078113972184607
# career ==> 15308085513773655218
# such ==> 10554686591937588953
# as ==> 1292078113972184607
# Engineering ==> 15794550382381185553
# , ==> 2593208677638477497
# Science ==> 15794550382381185553
# and ==> 17571114184892886314
# Technology ==> 15794550382381185553
# , ==> 2593208677638477497
# Management ==> 15794550382381185553
# , ==> 2593208677638477497
# Commerce ==> 15794550382381185553
# , ==> 2593208677638477497
# Architecture ==> 15794550382381185553
# , ==> 2593208677638477497
# Law ==> 15794550382381185553
# , ==> 2593208677638477497
# Economics ==> 15794550382381185553
# , ==> 2593208677638477497
# Pharmacy ==> 15794550382381185553
# , ==> 2593208677638477497
# Aviation ==> 15794550382381185553
# , ==> 2593208677638477497
# Design ==> 15794550382381185553
# , ==> 2593208677638477497
# Performing ==> 1534113631682161808
# Arts ==> 783433942507015291
# , ==> 2593208677638477497
# Liberal ==> 15794550382381185553
# Arts ==> 15794550382381185553
# , ==> 2593208677638477497
# Hospitality ==> 15794550382381185553
# Management ==> 15794550382381185553
# , ==> 2593208677638477497
# Mathematical ==> 15794550382381185553
# Science ==> 15794550382381185553
# , ==> 2593208677638477497
# Branding ==> 15794550382381185553
# and ==> 17571114184892886314
# Advertising ==> 15794550382381185553
# , ==> 2593208677638477497
# Agricultural ==> 15794550382381185553
# Sciences ==> 11233576250605462493
# and ==> 17571114184892886314
# much ==> 164681854541413346
# more ==> 272890857012483650
# .. ==> 12646065887601541794
# Ideal ==> 10554686591937588953
# for ==> 1292078113972184607
# forward ==> 164681854541413346
# - ==> 8214596291009089021
# thinking ==> 15308085513773655218
# and ==> 17571114184892886314
# new ==> 10554686591937588953
# - ==> 8214596291009089021
# age ==> 15308085513773655218
# young ==> 10554686591937588953
# professionals ==> 783433942507015291
# . ==> 12646065887601541794
# Strong ==> 10554686591937588953
# industry ==> 15308085513773655218
# interface ==> 15308085513773655218
# & ==> 17571114184892886314
# corporate ==> 10554686591937588953
# relationships ==> 783433942507015291
# with ==> 1292078113972184607
# 1348 ==> 8427216679587749980
# + ==> 8427216679587749980
# companies ==> 783433942507015291
# . ==> 12646065887601541794
# Research ==> 15308085513773655218
# - ==> 8214596291009089021
# backed ==> 3822385049556375858
# updated ==> 3822385049556375858
# curriculum ==> 15308085513773655218
# , ==> 2593208677638477497
# along ==> 1292078113972184607
# with ==> 1292078113972184607
# 2400 ==> 8427216679587749980
# + ==> 17571114184892886314
# published ==> 3822385049556375858
# papers ==> 783433942507015291
# to ==> 1292078113972184607
# its ==> 4062917326063685704
# credit ==> 15308085513773655218
# . ==> 12646065887601541794
# Continuing ==> 1534113631682161808
# the ==> 15267657372422890137
# legacy ==> 15308085513773655218
# of ==> 1292078113972184607
# quality ==> 15308085513773655218
# education ==> 15308085513773655218
# . ==> 12646065887601541794
# Focus ==> 15308085513773655218
# on ==> 1292078113972184607
# employability ==> 15308085513773655218
# of ==> 1292078113972184607
# students ==> 783433942507015291
# through ==> 1292078113972184607
# evolved ==> 3822385049556375858
# pedagogy ==> 15308085513773655218
# . ==> 12646065887601541794
# Pursuing ==> 1534113631682161808
# excellence ==> 15308085513773655218
# in ==> 1292078113972184607
# technological ==> 10554686591937588953
# and ==> 17571114184892886314
# management ==> 15308085513773655218
# research ==> 15308085513773655218

# %% [markdown]
# ## POS

# %%
for token in doc_1:
    print(token.text,'==>',token.pos_)
# Out:
# NMIMS ==> NOUN
# is ==> AUX
# the ==> DET
# all ==> ADV
# - ==> PUNCT
# encompassing ==> VERB
# educational ==> ADJ
# platform ==> NOUN
# for ==> ADP
# diverse ==> ADJ
# fields ==> NOUN
# of ==> ADP
# career ==> NOUN
# such ==> ADJ
# as ==> ADP
# Engineering ==> PROPN
# , ==> PUNCT
# Science ==> PROPN
# and ==> CCONJ
# Technology ==> PROPN
# , ==> PUNCT
# Management ==> PROPN
# , ==> PUNCT
# Commerce ==> PROPN
# , ==> PUNCT
# Architecture ==> PROPN
# , ==> PUNCT
# Law ==> PROPN
# , ==> PUNCT
# Economics ==> PROPN
# , ==> PUNCT
# Pharmacy ==> PROPN
# , ==> PUNCT
# Aviation ==> PROPN
# , ==> PUNCT
# Design ==> PROPN
# , ==> PUNCT
# Performing ==> VERB
# Arts ==> NOUN
# , ==> PUNCT
# Liberal ==> PROPN
# Arts ==> PROPN
# , ==> PUNCT
# Hospitality ==> PROPN
# Management ==> PROPN
# , ==> PUNCT
# Mathematical ==> PROPN
# Science ==> PROPN
# , ==> PUNCT
# Branding ==> PROPN
# and ==> CCONJ
# Advertising ==> PROPN
# , ==> PUNCT
# Agricultural ==> PROPN
# Sciences ==> PROPN
# and ==> CCONJ
# much ==> ADV
# more ==> ADJ
# .. ==> PUNCT
# Ideal ==> ADJ
# for ==> ADP
# forward ==> ADV
# - ==> PUNCT
# thinking ==> NOUN
# and ==> CCONJ
# new ==> ADJ
# - ==> PUNCT
# age ==> NOUN
# young ==> ADJ
# professionals ==> NOUN
# . ==> PUNCT
# Strong ==> ADJ
# industry ==> NOUN
# interface ==> NOUN
# & ==> CCONJ
# corporate ==> ADJ
# relationships ==> NOUN
# with ==> ADP
# 1348 ==> NUM
# + ==> NUM
# companies ==> NOUN
# . ==> PUNCT
# Research ==> NOUN
# - ==> PUNCT
# backed ==> VERB
# updated ==> VERB
# curriculum ==> NOUN
# , ==> PUNCT
# along ==> ADP
# with ==> ADP
# 2400 ==> NUM
# + ==> CCONJ
# published ==> VERB
# papers ==> NOUN
# to ==> ADP
# its ==> PRON
# credit ==> NOUN
# . ==> PUNCT
# Continuing ==> VERB
# the ==> DET
# legacy ==> NOUN
# of ==> ADP
# quality ==> NOUN
# education ==> NOUN
# . ==> PUNCT
# Focus ==> NOUN
# on ==> ADP
# employability ==> NOUN
# of ==> ADP
# students ==> NOUN
# through ==> ADP
# evolved ==> VERB
# pedagogy ==> NOUN
# . ==> PUNCT
# Pursuing ==> VERB
# excellence ==> NOUN
# in ==> ADP
# technological ==> ADJ
# and ==> CCONJ
# management ==> NOUN
# research ==> NOUN

# %%
for token in doc_1:
    print(token.text,'==>',token.pos)
# Out:
# NMIMS ==> 92
# is ==> 87
# the ==> 90
# all ==> 86
# - ==> 97
# encompassing ==> 100
# educational ==> 84
# platform ==> 92
# for ==> 85
# diverse ==> 84
# fields ==> 92
# of ==> 85
# career ==> 92
# such ==> 84
# as ==> 85
# Engineering ==> 96
# , ==> 97
# Science ==> 96
# and ==> 89
# Technology ==> 96
# , ==> 97
# Management ==> 96
# , ==> 97
# Commerce ==> 96
# , ==> 97
# Architecture ==> 96
# , ==> 97
# Law ==> 96
# , ==> 97
# Economics ==> 96
# , ==> 97
# Pharmacy ==> 96
# , ==> 97
# Aviation ==> 96
# , ==> 97
# Design ==> 96
# , ==> 97
# Performing ==> 100
# Arts ==> 92
# , ==> 97
# Liberal ==> 96
# Arts ==> 96
# , ==> 97
# Hospitality ==> 96
# Management ==> 96
# , ==> 97
# Mathematical ==> 96
# Science ==> 96
# , ==> 97
# Branding ==> 96
# and ==> 89
# Advertising ==> 96
# , ==> 97
# Agricultural ==> 96
# Sciences ==> 96
# and ==> 89
# much ==> 86
# more ==> 84
# .. ==> 97
# Ideal ==> 84
# for ==> 85
# forward ==> 86
# - ==> 97
# thinking ==> 92
# and ==> 89
# new ==> 84
# - ==> 97
# age ==> 92
# young ==> 84
# professionals ==> 92
# . ==> 97
# Strong ==> 84
# industry ==> 92
# interface ==> 92
# & ==> 89
# corporate ==> 84
# relationships ==> 92
# with ==> 85
# 1348 ==> 93
# + ==> 93
# companies ==> 92
# . ==> 97
# Research ==> 92
# - ==> 97
# backed ==> 100
# updated ==> 100
# curriculum ==> 92
# , ==> 97
# along ==> 85
# with ==> 85
# 2400 ==> 93
# + ==> 89
# published ==> 100
# papers ==> 92
# to ==> 85
# its ==> 95
# credit ==> 92
# . ==> 97
# Continuing ==> 100
# the ==> 90
# legacy ==> 92
# of ==> 85
# quality ==> 92
# education ==> 92
# . ==> 97
# Focus ==> 92
# on ==> 85
# employability ==> 92
# of ==> 85
# students ==> 92
# through ==> 85
# evolved ==> 100
# pedagogy ==> 92
# . ==> 97
# Pursuing ==> 100
# excellence ==> 92
# in ==> 85
# technological ==> 84
# and ==> 89
# management ==> 92
# research ==> 92

# %% [markdown]
# ## POS count

# %%
pos_count=doc_1.count_by(spacy.attrs.POS)
pos_count
# Out:
# {92: 26,
#  87: 1,
#  90: 2,
#  86: 3,
#  97: 26,
#  100: 8,
#  84: 10,
#  85: 13,
#  96: 21,
#  89: 7,
#  93: 3,
#  95: 1}

# %%
for x,y in sorted(pos_count.items()):
    print(x,doc_1.vocab[x].text,y)
# Out:
# 84 ADJ 10
# 85 ADP 13
# 86 ADV 3
# 87 AUX 1
# 89 CCONJ 7
# 90 DET 2
# 92 NOUN 26
# 93 NUM 3
# 95 PRON 1
# 96 PROPN 21
# 97 PUNCT 26
# 100 VERB 8

# %% [markdown]
# ## Visualisation of POS

# %%
from spacy import displacy
displacy.render(doc_1,style='dep') # Dependence
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7cfb1ae405b14cda9d24dbc184e91e82-0" class="displacy" width="16500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">NMIMS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">all-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">encompassing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">educational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">platform</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">diverse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">fields</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">career</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">such</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Engineering,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Technology,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Management,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Commerce,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Architecture,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Law,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Economics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Pharmacy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Aviation,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Design,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Performing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Arts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Liberal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Arts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="53

# %%
options={'compact':'True','color':'blue'}

displacy.render(doc_1,style='dep',options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b997b9b8eb9940658d14185ad33ffe5b-0" class="displacy" width="14150" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: blue; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">NMIMS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">all-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">encompassing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">educational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">platform</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">diverse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">fields</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">career</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">such</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Engineering,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">Technology,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Management,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">Commerce,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Architecture,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Law,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">Economics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">Pharmacy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Aviation,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">Design,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">Performing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">Arts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Liberal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">Arts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">H

# %% [markdown]
# ## COnverting a text into a DF with tokens, pos

# %%
text_df
# Out:
#                   Sentence
# 0          Today is Monday
# 1      Tomorrow is Tuesday
# 2  Yesterday was a holiday

# %%
token=[]
for sent in nlp.pipe(text_df['Sentence']):
    if sent.has_annotation('DEP'):
        token.append([word.text for word in sent] )
token
# Out:
# [['Today', 'is', 'Monday'],
#  ['Tomorrow', 'is', 'Tuesday'],
#  ['Yesterday', 'was', 'a', 'holiday']]

# %%
token=[]
pos=[]
for sent in nlp.pipe(text_df['Sentence']):
    if sent.has_annotation('DEP'):
        token.append([word.text for word in sent] )
        pos.append([word.pos_ for word in sent])
print(token)
print(pos)
# Out:
# [['Today', 'is', 'Monday'], ['Tomorrow', 'is', 'Tuesday'], ['Yesterday', 'was', 'a', 'holiday']]
# [['NOUN', 'AUX', 'PROPN'], ['NOUN', 'AUX', 'PROPN'], ['NOUN', 'AUX', 'DET', 'NOUN']]

# %%
# Updating text_df

text_df['Token']=token
text_df['POS']=pos

# %%
text_df
# Out:
#                   Sentence                         Token  \
# 0          Today is Monday           [Today, is, Monday]
# 1      Tomorrow is Tuesday       [Tomorrow, is, Tuesday]
# 2  Yesterday was a holiday  [Yesterday, was, a, holiday]
#
#                       POS
# 0      [NOUN, AUX, PROPN]
# 1      [NOUN, AUX, PROPN]
# 2  [NOUN, AUX, DET, NOUN]
