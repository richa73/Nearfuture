# %% [markdown]
# # Preprocessing using spacy

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc1=nlp('India, a South Asian nation, is the seventh-largest country by area, the second-most populous country with over 1.38 billion people, and the most populous democracy in the world. India boasts of an immensely rich cultural heritage, including numerous languages, traditions, and people. The country holds its uniqueness in its diversity, and hence has adapted itself to international changes with poise and comfort. While the economy has welcomed international companies to invest in it with open arms since liberalisation in the 1990s, Indians have been prudent and proactive in adopting global approaches and skills. Indian villagers have proudly taken up farming, advanced agriculture and unique handicrafts as their profession on one hand, while the modern industries and professional services sectors are coming up in a big way on the other.Thus, the country is attracting many global majors for strategic investments owing to the presence of a vast range of industries, investment avenues and a supportive Government. A huge population, mostly comprising the youth, is a strong driver for demand and an ample source of manpower.')

# %%
type(doc1)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ## Tokenization

# %%
for token in doc1:
    print(token)
# Out:
# India
# ,
# a
# South
# Asian
# nation
# ,
# is
# the
# seventh
# -
# largest
# country
# by
# area
# ,
# the
# second
# -
# most
# populous
# country
# with
# over
# 1.38
# billion
# people
# ,
# and
# the
# most
# populous
# democracy
# in
# the
# world
# .
# India
# boasts
# of
# an
# immensely
# rich
# cultural
# heritage
# ,
# including
# numerous
# languages
# ,
# traditions
# ,
# and
# people
# .
# The
# country
# holds
# its
# uniqueness
# in
# its
# diversity
# ,
# and
# hence
# has
# adapted
# itself
# to
# international
# changes
# with
# poise
# and
# comfort
# .
# While
# the
# economy
# has
# welcomed
# international
# companies
# to
# invest
# in
# it
# with
# open
# arms
# since
# liberalisation
# in
# the
# 1990s
# ,
# Indians
# have
# been
# prudent
# and
# proactive
# in
# adopting
# global
# approaches
# and
# skills
# .
# Indian
# villagers
# have
# proudly
# taken
# up
# farming
# ,
# advanced
# agriculture
# and
# unique
# handicrafts
# as
# their
# profession
# on
# one
# hand
# ,
# while
# the
# modern
# industries
# and
# professional
# services
# sectors
# are
# coming
# up
# in
# a
# big
# way
# on
# the
# other
# .
# Thus
# ,
# the
# country
# is
# attracting
# many
# global
# majors
# for
# strategic
# investments
# owing
# to
# the
# presence
# of
# a
# vast
# range
# of
# industries
# ,
# investment
# avenues
# and
# a
# supportive
# Government
# .
# A
# huge
# population
# ,
# mostly
# comprising
# the
# youth
# ,
# is
# a
# strong
# driver
# for
# demand
# and
# an
# ample
# source
# of
# manpower
# .

# %%
len(doc1)
# Out:
# 201

# %%
# Count the number of tokens

t_count=0
for token in doc1:
    t_count=t_count+1
    print(token)
print('The no of tokens:',t_count)
# Out:
# India
# ,
# a
# South
# Asian
# nation
# ,
# is
# the
# seventh
# -
# largest
# country
# by
# area
# ,
# the
# second
# -
# most
# populous
# country
# with
# over
# 1.38
# billion
# people
# ,
# and
# the
# most
# populous
# democracy
# in
# the
# world
# .
# India
# boasts
# of
# an
# immensely
# rich
# cultural
# heritage
# ,
# including
# numerous
# languages
# ,
# traditions
# ,
# and
# people
# .
# The
# country
# holds
# its
# uniqueness
# in
# its
# diversity
# ,
# and
# hence
# has
# adapted
# itself
# to
# international
# changes
# with
# poise
# and
# comfort
# .
# While
# the
# economy
# has
# welcomed
# international
# companies
# to
# invest
# in
# it
# with
# open
# arms
# since
# liberalisation
# in
# the
# 1990s
# ,
# Indians
# have
# been
# prudent
# and
# proactive
# in
# adopting
# global
# approaches
# and
# skills
# .
# Indian
# villagers
# have
# proudly
# taken
# up
# farming
# ,
# advanced
# agriculture
# and
# unique
# handicrafts
# as
# their
# profession
# on
# one
# hand
# ,
# while
# the
# modern
# industries
# and
# professional
# services
# sectors
# are
# coming
# up
# in
# a
# big
# way
# on
# the
# other
# .
# Thus
# ,
# the
# country
# is
# attracting
# many
# global
# majors
# for
# strategic
# investments
# owing
# to
# the
# presence
# of
# a
# vast
# range
# of
# industries
# ,
# investment
# avenues
# and
# a
# supportive
# Government
# .
# A
# huge
# population
# ,
# mostly
# comprising
# the
# youth
# ,
# is
# a
# strong
# driver
# for
# demand
# and
# an
# ample
# source
# of
# manpower
# .
# The no of tokens: 201

# %% [markdown]
# ## Stop words

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'when', 'who', 'seemed', 'or', 'first', 'perhaps', 'we', 'that', 'above', 'see', 'go', "'s", 'others', 'there', 'behind', 'done', 'without', 'does', 'mine', 'but', 'be', 'as', 'either', 'eight', 'serious', 'thus', 'keep', 'they', 'hundred', 'in', 'nor', 'whereafter', 'due', '’m', 'throughout', 'regarding', 'call', 'whenever', 'anyway', 'whose', 'take', 'our', 'became', 'well', 'yours', 'at', 'through', 'amongst', 'could', '‘ll', 'ever', 'few', 'thru', "n't", 'nine', 'would', 'why', 'itself', 'she', 'you', 'this', '’d', 'under', 'further', 'other', 'neither', "'d", 'nowhere', 'latterly', 'side', 'thereafter', 'which', 'whom', 'himself', 'ten', 'nevertheless', 'both', 'since', 'twenty', 'herself', 'across', 'becoming', 'toward', 'whereas', 'of', 'until', 'doing', 'therefore', 'for', 'also', 'else', 'everything', 'five', 'my', 'might', 'up', 're', 'do', 'somewhere', 'an', 'anyhow', 'how', 'her', 'own', 'whither', 'everywhere', 'while', 'its', "'ll", 'about', 'towards', 'every', 'nothing', 'hers', 'fifty', 'move', 'too', 'six', 'he', 'along', 'during', 'their', 'before', 'always', 'his', 'must', 'into', 'yourself', 'therein', 'amount', '’ll', 'almost', 'had', 'among', 'empty', 'however', 'those', 'hereafter', 'whereby', 'can', 'third', 'herein', 'three', '‘ve', 'really', 'except', 'within', 'used', 'most', 'same', 'did', 'hence', 'alone', 'a', 'than', 'sixty', 'via', 'whence', 'though', 'anywhere', 'noone', 'sometimes', 'get', 'against', 'were', '’ve', 'around', 'whereupon', 'where', 'and', 'former', 'no', 'yet', 'although', 'various', 'only', 'twelve', 'just', 'together', 'over', 'become', 'namely', 'latter', 'full', 'onto', 'show', 'rather', 'cannot', 'not', 'from', 'myself', 'using', 'make', 'if', 'been', 'hereby', '’re', 'last', 'these', 'front', 'anyone', 'none', 'wherein', 'seeming', 'very', 'even', 'moreover', 'am', 'bottom', 'formerly', 'much', "'ve", 'him', 'between', 'has', 'i', 'somehow', 'unless', 'may', 'more', 'yourselves', 'made', 'never', 'someone', 'down', 'us', 'whoever', 'several', 'top', 'have', 'fifteen', 'me', 'nobody', 'ours', 'on', 'ca', 'what', 'such', 'ourselves', 'name', 'afterwards', 'upon', 'everyone', 'back', 'beside', 'once', 'part', 'out', '‘m', 'meanwhile', 'eleven', 'them', 'here', 'some', 'put', 'quite', '‘s', 'least', 'enough', 'below', 'your', 'off', 'whatever', 'it', 'so', 'give', 'please', 'after', 'elsewhere', 'often', 'because', 'besides', 'thereupon', 'all', 'seem', 'next', 'should', 'another', 'being', "'m", 'thereby', 'already', 'per', 'by', 'mostly', 'say', 'less', 'any', 'whole', 'was', '‘d', 'beyond', 'to', 'thence', 'are', 'then', 'forty', 'n‘t', 'whether', 'something', 'still', 'otherwise', 'indeed', 'many', 'sometime', 'will', 'n’t', 'seems', 'with', 'again', '‘re', 'themselves', 'is', 'the', 'hereupon', 'each', 'beforehand', "'re", 'becomes', 'two', '’s', 'now', 'one', 'four', 'wherever', 'anything'}

# %%
len(STOP_WORDS)
# Out:
# 326

# %% [markdown]
# ## Is it a stop word

# %%
for token in doc1:
    print(token,'==>',token.is_stop)
# Out:
# India ==> False
# , ==> False
# a ==> True
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> True
# the ==> True
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> True
# area ==> False
# , ==> False
# the ==> True
# second ==> False
# - ==> False
# most ==> True
# populous ==> False
# country ==> False
# with ==> True
# over ==> True
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> True
# the ==> True
# most ==> True
# populous ==> False
# democracy ==> False
# in ==> True
# the ==> True
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> True
# an ==> True
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> True
# people ==> False
# . ==> False
# The ==> True
# country ==> False
# holds ==> False
# its ==> True
# uniqueness ==> False
# in ==> True
# its ==> True
# diversity ==> False
# , ==> False
# and ==> True
# hence ==> True
# has ==> True
# adapted ==> False
# itself ==> True
# to ==> True
# international ==> False
# changes ==> False
# with ==> True
# poise ==> False
# and ==> True
# comfort ==> False
# . ==> False
# While ==> True
# the ==> True
# economy ==> False
# has ==> True
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> True
# invest ==> False
# in ==> True
# it ==> True
# with ==> True
# open ==> False
# arms ==> False
# since ==> True
# liberalisation ==> False
# in ==> True
# the ==> True
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> True
# been ==> True
# prudent ==> False
# and ==> True
# proactive ==> False
# in ==> True
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> True
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> True
# proudly ==> False
# taken ==> False
# up ==> True
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> True
# unique ==> False
# handicrafts ==> False
# as ==> True
# their ==> True
# profession ==> False
# on ==> True
# one ==> True
# hand ==> False
# , ==> False
# while ==> True
# the ==> True
# modern ==> False
# industries ==> False
# and ==> True
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> True
# coming ==> False
# up ==> True
# in ==> True
# a ==> True
# big ==> False
# way ==> False
# on ==> True
# the ==> True
# other ==> True
# . ==> False
# Thus ==> True
# , ==> False
# the ==> True
# country ==> False
# is ==> True
# attracting ==> False
# many ==> True
# global ==> False
# majors ==> False
# for ==> True
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> True
# the ==> True
# presence ==> False
# of ==> True
# a ==> True
# vast ==> False
# range ==> False
# of ==> True
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> True
# a ==> True
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> True
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> True
# comprising ==> False
# the ==> True
# youth ==> False
# , ==> False
# is ==> True
# a ==> True
# strong ==> False
# driver ==> False
# for ==> True
# demand ==> False
# and ==> True
# an ==> True
# ample ==> False
# source ==> False
# of ==> True
# manpower ==> False
# . ==> False

# %%
# Count the no of non-stop words
s_count=0
for token in doc1:
    print(token,'==>',token.is_stop)
print('\n\n The non-stop words:\n')
for token in doc1:
    if token.is_stop==False:
        s_count=s_count+1
        print(token)
print('\n The count of non-stop words:',s_count)
# Out:
# India ==> False
# , ==> False
# a ==> True
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> True
# the ==> True
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> True
# area ==> False
# , ==> False
# the ==> True
# second ==> False
# - ==> False
# most ==> True
# populous ==> False
# country ==> False
# with ==> True
# over ==> True
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> True
# the ==> True
# most ==> True
# populous ==> False
# democracy ==> False
# in ==> True
# the ==> True
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> True
# an ==> True
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> True
# people ==> False
# . ==> False
# The ==> True
# country ==> False
# holds ==> False
# its ==> True
# uniqueness ==> False
# in ==> True
# its ==> True
# diversity ==> False
# , ==> False
# and ==> True
# hence ==> True
# has ==> True
# adapted ==> False
# itself ==> True
# to ==> True
# international ==> False
# changes ==> False
# with ==> True
# poise ==> False
# and ==> True
# comfort ==> False
# . ==> False
# While ==> True
# the ==> True
# economy ==> False
# has ==> True
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> True
# invest ==> False
# in ==> True
# it ==> True
# with ==> True
# open ==> False
# arms ==> False
# since ==> True
# liberalisation ==> False
# in ==> True
# the ==> True
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> True
# been ==> True
# prudent ==> False
# and ==> True
# proactive ==> False
# in ==> True
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> True
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> True
# proudly ==> False
# taken ==> False
# up ==> True
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> True
# unique ==> False
# handicrafts ==> False
# as ==> True
# their ==> True
# profession ==> False
# on ==> True
# one ==> True
# hand ==> False
# , ==> False
# while ==> True
# the ==> True
# modern ==> False
# industries ==> False
# and ==> True
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> True
# coming ==> False
# up ==> True
# in ==> True
# a ==> True
# big ==> False
# way ==> False
# on ==> True
# the ==> True
# other ==> True
# . ==> False
# Thus ==> True
# , ==> False
# the ==> True
# country ==> False
# is ==> True
# attracting ==> False
# many ==> True
# global ==> False
# majors ==> False
# for ==> True
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> True
# the ==> True
# presence ==> False
# of ==> True
# a ==> True
# vast ==> False
# range ==> False
# of ==> True
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> True
# a ==> True
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> True
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> True
# comprising ==> False
# the ==> True
# youth ==> False
# , ==> False
# is ==> True
# a ==> True
# strong ==> False
# driver ==> False
# for ==> True
# demand ==> False
# and ==> True
# an ==> True
# ample ==> False
# source ==> False
# of ==> True
# manpower ==> False
# . ==> False
#
#
#  The non-stop words:
#
# India
# ,
# South
# Asian
# nation
# ,
# seventh
# -
# largest
# country
# area
# ,
# second
# -
# populous
# country
# 1.38
# billion
# people
# ,
# populous
# democracy
# world
# .
# India
# boasts
# immensely
# rich
# cultural
# heritage
# ,
# including
# numerous
# languages
# ,
# traditions
# ,
# people
# .
# country
# holds
# uniqueness
# diversity
# ,
# adapted
# international
# changes
# poise
# comfort
# .
# economy
# welcomed
# international
# companies
# invest
# open
# arms
# liberalisation
# 1990s
# ,
# Indians
# prudent
# proactive
# adopting
# global
# approaches
# skills
# .
# Indian
# villagers
# proudly
# taken
# farming
# ,
# advanced
# agriculture
# unique
# handicrafts
# profession
# hand
# ,
# modern
# industries
# professional
# services
# sectors
# coming
# big
# way
# .
# ,
# country
# attracting
# global
# majors
# strategic
# investments
# owing
# presence
# vast
# range
# industries
# ,
# investment
# avenues
# supportive
# Government
# .
# huge
# population
# ,
# comprising
# youth
# ,
# strong
# driver
# demand
# ample
# source
# manpower
# .
#
#  The count of non-stop words: 121

# %% [markdown]
# ## Is it a punctuation ?

# %%
# Count the no of non-punctations
p_count=0
for token in doc1:
    print(token,'==>',token.is_punct)
print('\n\n The non-punctuation words:\n')
for token in doc1:
    if token.is_punct==False:
        p_count=p_count+1
        print(token)
print('\n The count of non-punctuations:',p_count)
# Out:
# India ==> False
# , ==> True
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> True
# is ==> False
# the ==> False
# seventh ==> False
# - ==> True
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> True
# the ==> False
# second ==> False
# - ==> True
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> True
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> True
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> True
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> True
# traditions ==> False
# , ==> True
# and ==> False
# people ==> False
# . ==> True
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> True
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> True
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> True
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> True
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> True
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> True
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> True
# Thus ==> False
# , ==> True
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> True
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> True
# A ==> False
# huge ==> False
# population ==> False
# , ==> True
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> True
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> True
#
#
#  The non-punctuation words:
#
# India
# a
# South
# Asian
# nation
# is
# the
# seventh
# largest
# country
# by
# area
# the
# second
# most
# populous
# country
# with
# over
# 1.38
# billion
# people
# and
# the
# most
# populous
# democracy
# in
# the
# world
# India
# boasts
# of
# an
# immensely
# rich
# cultural
# heritage
# including
# numerous
# languages
# traditions
# and
# people
# The
# country
# holds
# its
# uniqueness
# in
# its
# diversity
# and
# hence
# has
# adapted
# itself
# to
# international
# changes
# with
# poise
# and
# comfort
# While
# the
# economy
# has
# welcomed
# international
# companies
# to
# invest
# in
# it
# with
# open
# arms
# since
# liberalisation
# in
# the
# 1990s
# Indians
# have
# been
# prudent
# and
# proactive
# in
# adopting
# global
# approaches
# and
# skills
# Indian
# villagers
# have
# proudly
# taken
# up
# farming
# advanced
# agriculture
# and
# unique
# handicrafts
# as
# their
# profession
# on
# one
# hand
# while
# the
# modern
# industries
# and
# professional
# services
# sectors
# are
# coming
# up
# in
# a
# big
# way
# on
# the
# other
# Thus
# the
# country
# is
# attracting
# many
# global
# majors
# for
# strategic
# investments
# owing
# to
# the
# presence
# of
# a
# vast
# range
# of
# industries
# investment
# avenues
# and
# a
# supportive
# Government
# A
# huge
# population
# mostly
# comprising
# the
# youth
# is
# a
# strong
# driver
# for
# demand
# and
# an
# ample
# source
# of
# manpower
#
#  The count of non-punctuations: 177

# %%
# Count the no of punctations
p_count=0
for token in doc1:
    print(token,'==>',token.is_punct)
print('\n\n The punctuation words:\n')
for token in doc1:
    if token.is_punct==True:
        p_count=p_count+1
        print(token)
print('\n The count of punctuations:',p_count)
# Out:
# India ==> False
# , ==> True
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> True
# is ==> False
# the ==> False
# seventh ==> False
# - ==> True
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> True
# the ==> False
# second ==> False
# - ==> True
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> True
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> True
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> True
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> True
# traditions ==> False
# , ==> True
# and ==> False
# people ==> False
# . ==> True
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> True
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> True
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> True
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> True
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> True
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> True
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> True
# Thus ==> False
# , ==> True
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> True
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> True
# A ==> False
# huge ==> False
# population ==> False
# , ==> True
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> True
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> True
#
#
#  The punctuation words:
#
# ,
# ,
# -
# ,
# -
# ,
# .
# ,
# ,
# ,
# .
# ,
# .
# ,
# .
# ,
# ,
# .
# ,
# ,
# .
# ,
# ,
# .
#
#  The count of punctuations: 24

# %% [markdown]
# ## Is it a left punctuation

# %%
# Count the no of left punctations
lp_count=0
for token in doc1:
    print(token,'==>',token.is_left_punct)
print('\n\n The punctuation words:\n')
for token in doc1:
    if token.is_left_punct==True:
        lp_count=lp_count+1
        print(token)
print('\n The count of leftv punctuations:',lp_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> False
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The punctuation words:
#
#
#  The count of leftv punctuations: 0

# %% [markdown]
# ## Is it a right punctuation?

# %%
# Count the no of right punctations
rp_count=0
for token in doc1:
    print(token,'==>',token.is_right_punct)
print('\n\n The right punctuation words:\n')
for token in doc1:
    if token.is_right_punct==True:
        rp_count=rp_count+1
        print(token)
print('\n The count of right punctuations:',rp_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> False
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The right punctuation words:
#
#
#  The count of right punctuations: 0

# %% [markdown]
# ## Is it an alphabet?

# %%
# Count the tokens, whcih are made of alphabets
a_count=0
for token in doc1:
    print(token,'==>',token.is_alpha)
print('\n\n The alphabets tokens:\n')
for token in doc1:
    if token.is_alpha==True:
        a_count=a_count+1
        print(token)
print('\n The count of alphabet-tokens:',a_count)
# Out:
# India ==> True
# , ==> False
# a ==> True
# South ==> True
# Asian ==> True
# nation ==> True
# , ==> False
# is ==> True
# the ==> True
# seventh ==> True
# - ==> False
# largest ==> True
# country ==> True
# by ==> True
# area ==> True
# , ==> False
# the ==> True
# second ==> True
# - ==> False
# most ==> True
# populous ==> True
# country ==> True
# with ==> True
# over ==> True
# 1.38 ==> False
# billion ==> True
# people ==> True
# , ==> False
# and ==> True
# the ==> True
# most ==> True
# populous ==> True
# democracy ==> True
# in ==> True
# the ==> True
# world ==> True
# . ==> False
# India ==> True
# boasts ==> True
# of ==> True
# an ==> True
# immensely ==> True
# rich ==> True
# cultural ==> True
# heritage ==> True
# , ==> False
# including ==> True
# numerous ==> True
# languages ==> True
# , ==> False
# traditions ==> True
# , ==> False
# and ==> True
# people ==> True
# . ==> False
# The ==> True
# country ==> True
# holds ==> True
# its ==> True
# uniqueness ==> True
# in ==> True
# its ==> True
# diversity ==> True
# , ==> False
# and ==> True
# hence ==> True
# has ==> True
# adapted ==> True
# itself ==> True
# to ==> True
# international ==> True
# changes ==> True
# with ==> True
# poise ==> True
# and ==> True
# comfort ==> True
# . ==> False
# While ==> True
# the ==> True
# economy ==> True
# has ==> True
# welcomed ==> True
# international ==> True
# companies ==> True
# to ==> True
# invest ==> True
# in ==> True
# it ==> True
# with ==> True
# open ==> True
# arms ==> True
# since ==> True
# liberalisation ==> True
# in ==> True
# the ==> True
# 1990s ==> False
# , ==> False
# Indians ==> True
# have ==> True
# been ==> True
# prudent ==> True
# and ==> True
# proactive ==> True
# in ==> True
# adopting ==> True
# global ==> True
# approaches ==> True
# and ==> True
# skills ==> True
# . ==> False
# Indian ==> True
# villagers ==> True
# have ==> True
# proudly ==> True
# taken ==> True
# up ==> True
# farming ==> True
# , ==> False
# advanced ==> True
# agriculture ==> True
# and ==> True
# unique ==> True
# handicrafts ==> True
# as ==> True
# their ==> True
# profession ==> True
# on ==> True
# one ==> True
# hand ==> True
# , ==> False
# while ==> True
# the ==> True
# modern ==> True
# industries ==> True
# and ==> True
# professional ==> True
# services ==> True
# sectors ==> True
# are ==> True
# coming ==> True
# up ==> True
# in ==> True
# a ==> True
# big ==> True
# way ==> True
# on ==> True
# the ==> True
# other ==> True
# . ==> False
# Thus ==> True
# , ==> False
# the ==> True
# country ==> True
# is ==> True
# attracting ==> True
# many ==> True
# global ==> True
# majors ==> True
# for ==> True
# strategic ==> True
# investments ==> True
# owing ==> True
# to ==> True
# the ==> True
# presence ==> True
# of ==> True
# a ==> True
# vast ==> True
# range ==> True
# of ==> True
# industries ==> True
# , ==> False
# investment ==> True
# avenues ==> True
# and ==> True
# a ==> True
# supportive ==> True
# Government ==> True
# . ==> False
# A ==> True
# huge ==> True
# population ==> True
# , ==> False
# mostly ==> True
# comprising ==> True
# the ==> True
# youth ==> True
# , ==> False
# is ==> True
# a ==> True
# strong ==> True
# driver ==> True
# for ==> True
# demand ==> True
# and ==> True
# an ==> True
# ample ==> True
# source ==> True
# of ==> True
# manpower ==> True
# . ==> False
#
#
#  The alphabets tokens:
#
# India
# a
# South
# Asian
# nation
# is
# the
# seventh
# largest
# country
# by
# area
# the
# second
# most
# populous
# country
# with
# over
# billion
# people
# and
# the
# most
# populous
# democracy
# in
# the
# world
# India
# boasts
# of
# an
# immensely
# rich
# cultural
# heritage
# including
# numerous
# languages
# traditions
# and
# people
# The
# country
# holds
# its
# uniqueness
# in
# its
# diversity
# and
# hence
# has
# adapted
# itself
# to
# international
# changes
# with
# poise
# and
# comfort
# While
# the
# economy
# has
# welcomed
# international
# companies
# to
# invest
# in
# it
# with
# open
# arms
# since
# liberalisation
# in
# the
# Indians
# have
# been
# prudent
# and
# proactive
# in
# adopting
# global
# approaches
# and
# skills
# Indian
# villagers
# have
# proudly
# taken
# up
# farming
# advanced
# agriculture
# and
# unique
# handicrafts
# as
# their
# profession
# on
# one
# hand
# while
# the
# modern
# industries
# and
# professional
# services
# sectors
# are
# coming
# up
# in
# a
# big
# way
# on
# the
# other
# Thus
# the
# country
# is
# attracting
# many
# global
# majors
# for
# strategic
# investments
# owing
# to
# the
# presence
# of
# a
# vast
# range
# of
# industries
# investment
# avenues
# and
# a
# supportive
# Government
# A
# huge
# population
# mostly
# comprising
# the
# youth
# is
# a
# strong
# driver
# for
# demand
# and
# an
# ample
# source
# of
# manpower
#
#  The count of alphabet-tokens: 175

# %% [markdown]
# ## is it a digit?

# %%
# Count the no of digits
d_count=0
for token in doc1:
    print(token,'==>',token.is_digit)
print('\n\n The digits:\n')
for token in doc1:
    if token.is_digit==True:
        d_count=d_count+1
        print(token)
print('\n The count of digits:',d_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> False
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The digits:
#
#
#  The count of digits: 0

# %%
doc2=nlp('1000 is a big number')
for token in doc2:
    print(token,'==>',token.is_digit)
# Out:
# 1000 ==> True
# is ==> False
# a ==> False
# big ==> False
# number ==> False

# %% [markdown]
# ## Is it  lower case ?

# %%
# Count the no of lower case tokens
l_count=0
for token in doc1:
    print(token,'==>',token.is_lower)
print('\n\n The lower case words:\n')
for token in doc1:
    if token.is_lower==True:
        l_count=l_count+1
        print(token)
print('\n The count of lower case tokens:',l_count)
# Out:
# India ==> False
# , ==> False
# a ==> True
# South ==> False
# Asian ==> False
# nation ==> True
# , ==> False
# is ==> True
# the ==> True
# seventh ==> True
# - ==> False
# largest ==> True
# country ==> True
# by ==> True
# area ==> True
# , ==> False
# the ==> True
# second ==> True
# - ==> False
# most ==> True
# populous ==> True
# country ==> True
# with ==> True
# over ==> True
# 1.38 ==> False
# billion ==> True
# people ==> True
# , ==> False
# and ==> True
# the ==> True
# most ==> True
# populous ==> True
# democracy ==> True
# in ==> True
# the ==> True
# world ==> True
# . ==> False
# India ==> False
# boasts ==> True
# of ==> True
# an ==> True
# immensely ==> True
# rich ==> True
# cultural ==> True
# heritage ==> True
# , ==> False
# including ==> True
# numerous ==> True
# languages ==> True
# , ==> False
# traditions ==> True
# , ==> False
# and ==> True
# people ==> True
# . ==> False
# The ==> False
# country ==> True
# holds ==> True
# its ==> True
# uniqueness ==> True
# in ==> True
# its ==> True
# diversity ==> True
# , ==> False
# and ==> True
# hence ==> True
# has ==> True
# adapted ==> True
# itself ==> True
# to ==> True
# international ==> True
# changes ==> True
# with ==> True
# poise ==> True
# and ==> True
# comfort ==> True
# . ==> False
# While ==> False
# the ==> True
# economy ==> True
# has ==> True
# welcomed ==> True
# international ==> True
# companies ==> True
# to ==> True
# invest ==> True
# in ==> True
# it ==> True
# with ==> True
# open ==> True
# arms ==> True
# since ==> True
# liberalisation ==> True
# in ==> True
# the ==> True
# 1990s ==> True
# , ==> False
# Indians ==> False
# have ==> True
# been ==> True
# prudent ==> True
# and ==> True
# proactive ==> True
# in ==> True
# adopting ==> True
# global ==> True
# approaches ==> True
# and ==> True
# skills ==> True
# . ==> False
# Indian ==> False
# villagers ==> True
# have ==> True
# proudly ==> True
# taken ==> True
# up ==> True
# farming ==> True
# , ==> False
# advanced ==> True
# agriculture ==> True
# and ==> True
# unique ==> True
# handicrafts ==> True
# as ==> True
# their ==> True
# profession ==> True
# on ==> True
# one ==> True
# hand ==> True
# , ==> False
# while ==> True
# the ==> True
# modern ==> True
# industries ==> True
# and ==> True
# professional ==> True
# services ==> True
# sectors ==> True
# are ==> True
# coming ==> True
# up ==> True
# in ==> True
# a ==> True
# big ==> True
# way ==> True
# on ==> True
# the ==> True
# other ==> True
# . ==> False
# Thus ==> False
# , ==> False
# the ==> True
# country ==> True
# is ==> True
# attracting ==> True
# many ==> True
# global ==> True
# majors ==> True
# for ==> True
# strategic ==> True
# investments ==> True
# owing ==> True
# to ==> True
# the ==> True
# presence ==> True
# of ==> True
# a ==> True
# vast ==> True
# range ==> True
# of ==> True
# industries ==> True
# , ==> False
# investment ==> True
# avenues ==> True
# and ==> True
# a ==> True
# supportive ==> True
# Government ==> False
# . ==> False
# A ==> False
# huge ==> True
# population ==> True
# , ==> False
# mostly ==> True
# comprising ==> True
# the ==> True
# youth ==> True
# , ==> False
# is ==> True
# a ==> True
# strong ==> True
# driver ==> True
# for ==> True
# demand ==> True
# and ==> True
# an ==> True
# ample ==> True
# source ==> True
# of ==> True
# manpower ==> True
# . ==> False
#
#
#  The lower case words:
#
# a
# nation
# is
# the
# seventh
# largest
# country
# by
# area
# the
# second
# most
# populous
# country
# with
# over
# billion
# people
# and
# the
# most
# populous
# democracy
# in
# the
# world
# boasts
# of
# an
# immensely
# rich
# cultural
# heritage
# including
# numerous
# languages
# traditions
# and
# people
# country
# holds
# its
# uniqueness
# in
# its
# diversity
# and
# hence
# has
# adapted
# itself
# to
# international
# changes
# with
# poise
# and
# comfort
# the
# economy
# has
# welcomed
# international
# companies
# to
# invest
# in
# it
# with
# open
# arms
# since
# liberalisation
# in
# the
# 1990s
# have
# been
# prudent
# and
# proactive
# in
# adopting
# global
# approaches
# and
# skills
# villagers
# have
# proudly
# taken
# up
# farming
# advanced
# agriculture
# and
# unique
# handicrafts
# as
# their
# profession
# on
# one
# hand
# while
# the
# modern
# industries
# and
# professional
# services
# sectors
# are
# coming
# up
# in
# a
# big
# way
# on
# the
# other
# the
# country
# is
# attracting
# many
# global
# majors
# for
# strategic
# investments
# owing
# to
# the
# presence
# of
# a
# vast
# range
# of
# industries
# investment
# avenues
# and
# a
# supportive
# huge
# population
# mostly
# comprising
# the
# youth
# is
# a
# strong
# driver
# for
# demand
# and
# an
# ample
# source
# of
# manpower
#
#  The count of lower case tokens: 165

# %% [markdown]
# ## Is it upper case?

# %%
# Count the no of upper case tokens
u_count=0
for token in doc1:
    print(token,'==>',token.is_upper)
print('\n\n The lower case words:\n')
for token in doc1:
    if token.is_upper==True:
        u_count=u_count+1
        print(token)
print('\n The count of upper case tokens:',u_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> True
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The lower case words:
#
# A
#
#  The count of upper case tokens: 1

# %% [markdown]
# ## Is it title case?

# %%
# Count the no of title case tokens
t_count=0
for token in doc1:
    print(token,'==>',token.is_title)
print('\n\n The title case words:\n')
for token in doc1:
    if token.is_title==True:
        t_count=t_count+1
        print(token)
print('\n The count of title case tokens:',t_count)
# Out:
# India ==> True
# , ==> False
# a ==> False
# South ==> True
# Asian ==> True
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> True
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> True
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> True
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> True
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> True
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> True
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> True
# . ==> False
# A ==> True
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The title case words:
#
# India
# South
# Asian
# India
# The
# While
# Indians
# Indian
# Thus
# Government
# A
#
#  The count of title case tokens: 11

# %% [markdown]
# ## Is it a bracket ?

# %%
# Count the no of bracket tokens
b_count=0
for token in doc1:
    print(token,'==>',token.is_bracket)
print('\n\n The bracket tokens:\n')
for token in doc1:
    if token.is_bracket==True:
        b_count=b_count+1
        print(token)
print('\n The count of bracket tokens:',b_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> False
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The bracket tokens:
#
#
#  The count of bracket tokens: 0

# %% [markdown]
# ## is it a quote?

# %%
# Count the no of quote tokens
q_count=0
for token in doc1:
    print(token,'==>',token.is_quote)
print('\n\n The quote words:\n')
for token in doc1:
    if token.is_quote==True:
        q_count=q_count+1
        print(token)
print('\n The count of quote tokens:',q_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> False
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> False
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> False
# billion ==> False
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> False
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> False
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The quote words:
#
#
#  The count of quote tokens: 0

# %% [markdown]
# ## is it like a number?

# %%
# Count the no tokens
n_count=0
for token in doc1:
    print(token,'==>',token.like_num)
print('\n\n The numbers:\n')
for token in doc1:
    if token.like_num==True:
        n_count=n_count+1
        print(token)
print('\n The count of number tokens:',n_count)
# Out:
# India ==> False
# , ==> False
# a ==> False
# South ==> False
# Asian ==> False
# nation ==> False
# , ==> False
# is ==> False
# the ==> False
# seventh ==> True
# - ==> False
# largest ==> False
# country ==> False
# by ==> False
# area ==> False
# , ==> False
# the ==> False
# second ==> True
# - ==> False
# most ==> False
# populous ==> False
# country ==> False
# with ==> False
# over ==> False
# 1.38 ==> True
# billion ==> True
# people ==> False
# , ==> False
# and ==> False
# the ==> False
# most ==> False
# populous ==> False
# democracy ==> False
# in ==> False
# the ==> False
# world ==> False
# . ==> False
# India ==> False
# boasts ==> False
# of ==> False
# an ==> False
# immensely ==> False
# rich ==> False
# cultural ==> False
# heritage ==> False
# , ==> False
# including ==> False
# numerous ==> False
# languages ==> False
# , ==> False
# traditions ==> False
# , ==> False
# and ==> False
# people ==> False
# . ==> False
# The ==> False
# country ==> False
# holds ==> False
# its ==> False
# uniqueness ==> False
# in ==> False
# its ==> False
# diversity ==> False
# , ==> False
# and ==> False
# hence ==> False
# has ==> False
# adapted ==> False
# itself ==> False
# to ==> False
# international ==> False
# changes ==> False
# with ==> False
# poise ==> False
# and ==> False
# comfort ==> False
# . ==> False
# While ==> False
# the ==> False
# economy ==> False
# has ==> False
# welcomed ==> False
# international ==> False
# companies ==> False
# to ==> False
# invest ==> False
# in ==> False
# it ==> False
# with ==> False
# open ==> False
# arms ==> False
# since ==> False
# liberalisation ==> False
# in ==> False
# the ==> False
# 1990s ==> False
# , ==> False
# Indians ==> False
# have ==> False
# been ==> False
# prudent ==> False
# and ==> False
# proactive ==> False
# in ==> False
# adopting ==> False
# global ==> False
# approaches ==> False
# and ==> False
# skills ==> False
# . ==> False
# Indian ==> False
# villagers ==> False
# have ==> False
# proudly ==> False
# taken ==> False
# up ==> False
# farming ==> False
# , ==> False
# advanced ==> False
# agriculture ==> False
# and ==> False
# unique ==> False
# handicrafts ==> False
# as ==> False
# their ==> False
# profession ==> False
# on ==> False
# one ==> True
# hand ==> False
# , ==> False
# while ==> False
# the ==> False
# modern ==> False
# industries ==> False
# and ==> False
# professional ==> False
# services ==> False
# sectors ==> False
# are ==> False
# coming ==> False
# up ==> False
# in ==> False
# a ==> False
# big ==> False
# way ==> False
# on ==> False
# the ==> False
# other ==> False
# . ==> False
# Thus ==> False
# , ==> False
# the ==> False
# country ==> False
# is ==> False
# attracting ==> False
# many ==> False
# global ==> False
# majors ==> False
# for ==> False
# strategic ==> False
# investments ==> False
# owing ==> False
# to ==> False
# the ==> False
# presence ==> False
# of ==> False
# a ==> False
# vast ==> False
# range ==> False
# of ==> False
# industries ==> False
# , ==> False
# investment ==> False
# avenues ==> False
# and ==> False
# a ==> False
# supportive ==> False
# Government ==> False
# . ==> False
# A ==> False
# huge ==> False
# population ==> False
# , ==> False
# mostly ==> False
# comprising ==> False
# the ==> False
# youth ==> False
# , ==> False
# is ==> False
# a ==> False
# strong ==> False
# driver ==> False
# for ==> False
# demand ==> False
# and ==> False
# an ==> False
# ample ==> False
# source ==> False
# of ==> False
# manpower ==> False
# . ==> False
#
#
#  The numbers:
#
# seventh
# second
# 1.38
# billion
# one
#
#  The count of number tokens: 5

# %% [markdown]
# ## Is it like a url?

# %%
doc3=nlp('The site of Times of India is www.timesofindia.com.')

# %%
for token in doc3:
    print(token.text,'==>',token.like_url)
# Out:
# The ==> False
# site ==> False
# of ==> False
# Times ==> False
# of ==> False
# India ==> False
# is ==> False
# www.timesofindia.com ==> True
# . ==> False

# %% [markdown]
# ## is it like an email ID?

# %%
doc4=nlp('My email ID is abc1234@nmims.edu')

# %%
for token in doc4:
    print(token.text,'==>',token.like_email)
# Out:
# My ==> False
# email ==> False
# ID ==> False
# is ==> False
# abc1234@nmims.edu ==> True

# %%
doc4=nlp('My email ID is abc1234@nmims.edu.in')

# %%
for token in doc4:
    print(token.text,'==>',token.like_email)
# Out:
# My ==> False
# email ==> False
# ID ==> False
# is ==> False
# abc1234@nmims.edu.in ==> True

# %%
doc4=nlp(' My email ID is abc1234@nmims.edu.in, in the data')

# %%
for token in doc4:
    print(token.text,'==>',token.like_email)
# Out:
#   ==> False
# My ==> False
# email ==> False
# ID ==> False
# is ==> False
# abc1234@nmims.edu.in ==> True
# , ==> False
# in ==> False
# the ==> False
# data ==> False

# %% [markdown]
# # Parts of Speech - POS

# %%
for token in doc2:
    print(token)
# Out:
# 1000
# is
# a
# big
# number

# %%
for token in doc2:
    print(token,'==>',token.pos_)
# Out:
# 1000 ==> NUM
# is ==> AUX
# a ==> DET
# big ==> ADJ
# number ==> NOUN

# %%
spacy.explain('AUX')
# Out:
# 'auxiliary'

# %% [markdown]
# ## Token in a DF

# %%
# Creating columns for the DF

cols=['Token','POS','Explain_POS','Tag','Explain_Tag']
cols
# Out:
# ['Token', 'POS', 'Explain_POS', 'Tag', 'Explain_Tag']

# %%
rows=[]
for token in doc1:
    row=token,token.pos_,spacy.explain(token.pos_),token.tag_,spacy.explain(token.tag_)
    rows.append(row)
rows
# Out:
# [(India, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (South,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (Asian,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (nation, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (seventh, 'ADV', 'adverb', 'RB', 'adverb'),
#  (-, 'PUNCT', 'punctuation', 'HYPH', 'punctuation mark, hyphen'),
#  (largest, 'ADJ', 'adjective', 'JJS', 'adjective, superlative'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (by, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (area, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (second, 'ADV', 'adverb', 'RB', 'adverb'),
#  (-, 'PUNCT', 'punctuation', 'HYPH', 'punctuation mark, hyphen'),
#  (most, 'ADV', 'adverb', 'RBS', 'adverb, superlative'),
#  (populous,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (with,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (over,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (1.38, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (billion, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (people, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (most, 'ADV', 'adverb', 'RBS', 'adverb, superlative'),
#  (populous,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (democracy, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (world, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (India, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (boasts, 'VERB', 'verb', 'VBZ', 'verb, 3rd person singular present'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (an, 'DET', 'determiner', 'DT', 'determiner'),
#  (immensely, 'ADV', 'adverb', 'RB', 'adverb'),
#  (rich,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (cultural,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (heritage, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (including, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (numerous,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (languages, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (traditions, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (people, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (The, 'DET', 'determiner', 'DT', 'determiner'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (holds, 'VERB', 'verb', 'VBZ', 'verb, 3rd person singular present'),
#  (its, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (uniqueness, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (its, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (diversity, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (hence, 'ADV', 'adverb', 'RB', 'adverb'),
#  (has, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (adapted, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (itself, 'PRON', 'pronoun', 'PRP', 'pronoun, personal'),
#  (to, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (international,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (changes, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (with,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (poise, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (comfort, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (While,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (economy, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (has, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (welcomed, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (international,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (companies, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (to, 'PART', 'particle', 'TO', 'infinitival "to"'),
#  (invest, 'VERB', 'verb', 'VB', 'verb, base form'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (it, 'PRON', 'pronoun', 'PRP', 'pronoun, personal'),
#  (with,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (open,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (arms, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (since,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (liberalisation, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (1990s, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (Indians, 'PROPN', 'proper noun', 'NNPS', 'noun, proper plural'),
#  (have, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (been, 'AUX', 'auxiliary', 'VBN', 'verb, past participle'),
#  (prudent,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (proactive,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (adopting, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (global,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (approaches, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (skills, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (Indian,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (villagers, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (have, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (proudly, 'ADV', 'adverb', 'RB', 'adverb'),
#  (taken, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (up, 'ADP', 'adposition', 'RP', 'adverb, particle'),
#  (farming, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (advanced,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (agriculture, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (unique,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (handicrafts, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (as, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (their, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (profession, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (one, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (hand, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (while,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (modern,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (industries, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (professional,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (services, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (sectors, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (are, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (coming, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (up, 'ADP', 'adposition', 'RP', 'adverb, particle'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (big,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (way, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (other,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (Thus, 'ADV', 'adverb', 'RB', 'adverb'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (attracting, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (many,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (global,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (majors, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (for, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (strategic,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (investments, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (owing, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (to, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (presence, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (vast,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (range, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (industries, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (investment, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (avenues, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (supportive,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (Government, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (A, 'DET', 'determiner', 'DT', 'determiner'),
#  (huge,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (population, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (mostly, 'ADV', 'adverb', 'RB', 'adverb'),
#  (comprising, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (youth, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (strong,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (driver, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (for, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (demand, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (an, 'DET', 'determiner', 'DT', 'determiner'),
#  (ample,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (source, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (manpower, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer')]

# %%
import pandas as pd
token_df=pd.DataFrame(rows,columns=cols)
token_df
# Out:
#         Token    POS  Explain_POS  Tag  \
# 0       India  PROPN  proper noun  NNP
# 1           ,  PUNCT  punctuation    ,
# 2           a    DET   determiner   DT
# 3       South    ADJ    adjective   JJ
# 4       Asian    ADJ    adjective   JJ
# ..        ...    ...          ...  ...
# 196     ample    ADJ    adjective   JJ
# 197    source   NOUN         noun   NN
# 198        of    ADP   adposition   IN
# 199  manpower   NOUN         noun   NN
# 200         .  PUNCT  punctuation    .
#
#                                            Explain_Tag
# 0                                noun, proper singular
# 1                              punctuation mark, comma
# 2                                           determiner
# 3    adjective (English), other noun-modifier (Chin...
# 4    adjective (English), other noun-modifier (Chin...
# ..                                                 ...
# 196  adjective (English), other noun-modifier (Chin...
# 197                             noun, singular or mass
# 198          conjunction, subordinating or preposition
# 199                             noun, singular or mass
# 200                  punctuation mark, sentence closer
#
# [201 rows x 5 columns]

# %%
token_df['POS'].value_counts()
# Out:
# NOUN     48
# ADJ      29
# PUNCT    24
# ADP      24
# DET      20
# VERB     12
# CCONJ    10
# AUX       9
# ADV       9
# PRON      5
# NUM       4
# PROPN     3
# SCONJ     3
# PART      1
# Name: POS, dtype: int64
